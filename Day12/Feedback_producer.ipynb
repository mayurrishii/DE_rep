# %%
from kafka import KafkaProducer
import pandas as pd
import json
import time

producer = KafkaProducer(
    bootstrap_servers='localhost:9092',
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

df = pd.read_csv("feedback_status.csv")

while True:
    for _, row in df.iterrows():

        data = {
            "user": row['user'],
            "restaurant": row['restaurant'],
            "rating": int(row['rating']),
            "comment": row['comment']
        }

        producer.send('feedback_topic', value=data)

        print("Feedback Sent:", data)

        time.sleep(4)
# Out:
# Feedback Sent: {'user': 'Alice', 'restaurant': 'Pizza Hut', 'rating': 5, 'comment': 'Great pizza!'}
# Feedback Sent: {'user': 'Bob', 'restaurant': 'Burger King', 'rating': 4, 'comment': 'Tasty burger'}
# Feedback Sent: {'user': 'Charlie', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast delivery'}
# Feedback Sent: {'user': 'David', 'restaurant': 'KFC', 'rating': 3, 'comment': 'Average food'}
# Feedback Sent: {'user': 'Alice', 'restaurant': 'Pizza Hut', 'rating': 5, 'comment': 'Great pizza!'}
# Feedback Sent: {'user': 'Bob', 'restaurant': 'Burger King', 'rating': 4, 'comment': 'Tasty burger'}
# Feedback Sent: {'user': 'Charlie', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast delivery'}
# Feedback Sent: {'user': 'David', 'restaurant': 'KFC', 'rating': 3, 'comment': 'Average food'}
# Feedback Sent: {'user': 'Alice', 'restaurant': 'Pizza Hut', 'rating': 5, 'comment': 'Great pizza!'}
# Feedback Sent: {'user': 'Bob', 'restaurant': 'Burger King', 'rating': 4, 'comment': 'Tasty burger'}
# Feedback Sent: {'user': 'Charlie', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast delivery'}
# Feedback Sent: {'user': 'David', 'restaurant': 'KFC', 'rating': 3, 'comment': 'Average food'}
# Feedback Sent: {'user': 'Alice', 'restaurant': 'Pizza Hut', 'rating': 5, 'comment': 'Great pizza!'}
# Feedback Sent: {'user': 'Bob', 'restaurant': 'Burger King', 'rating': 4, 'comment': 'Tasty burger'}
# Feedback Sent: {'user': 'Charlie', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast delivery'}
# Feedback Sent: {'user': 'David', 'restaurant': 'KFC', 'rating': 3, 'comment': 'Average food'}
# Feedback Sent: {'user': 'Alice', 'restaurant': 'Pizza Hut', 'rating': 5, 'comment': 'Great pizza!'}
# Feedback Sent: {'user': 'Bob', 'restaurant': 'Burger King', 'rating': 4, 'comment': 'Tasty burger'}
# Feedback Sent: {'user': 'Charlie', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast delivery'}
# Feedback Sent: {'user': 'David', 'restaurant': 'KFC', 'rating': 3, 'comment': 'Average food'}
# Feedback Sent: {'user': 'Alice', 'restaurant': 'Pizza Hut', 'rating': 5, 'comment': 'Great pizza!'}
# Feedback Sent: {'user': 'Bob', 'restaurant': 'Burger King', 'rating': 4, 'comment': 'Tasty burger'}
# Feedback Sent: {'user': 'Charlie', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast delivery'}
# Feedback Sent: {'user': 'David', 'restaurant': 'KFC', 'rating': 3, 'comment': 'Average food'}
# Feedback Sent: {'user': 'Alice', 'restaurant': 'Pizza Hut', 'rating': 5, 'comment': 'Great pizza!'}
# Feedback Sent: {'user': 'Bob', 'restaurant': 'Burger King', 'rating': 4, 'comment': 'Tasty burger'}
# Feedback Sent: {'user': 'Charlie', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast delivery'}
# Feedback Sent: {'user': 'David', 'restaurant': 'KFC', 'rating': 3, 'comment': 'Average food'}
# Feedback Sent: {'user': 'Alice', 'restaurant': 'Pizza Hut', 'rating': 5, 'comment': 'Great pizza!'}
# Feedback Sent: {'user': 'Bob', 'restaurant': 'Burger King', 'rating': 4, 'comment': 'Tasty burger'}
# Feedback Sent: {'user': 'Charlie', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast delivery'}
# Feedback Sent: {'user': 'David', 'restaurant': 'KFC', 'rating': 3, 'comment': 'Average food'}
# Feedback Sent: {'user': 'Alice', 'restaurant': 'Pizza Hut', 'rating': 5, 'comment': 'Great pizza!'}
# Feedback Sent: {'user': 'Bob', 'restaurant': 'Burger King', 'rating': 4, 'comment': 'Tasty burger'}
# Feedback Sent: {'user': 'Charlie', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast delivery'}
# Feedback Sent: {'user': 'David', 'restaurant': 'KFC', 'rating': 3, 'comment': 'Average food'}
# Feedback Sent: {'user': 'Alice', 'restaurant': 'Pizza Hut', 'rating': 5, 'comment': 'Great pizza!'}
# Feedback Sent: {'user': 'Bob', 'restaurant': 'Burger King', 'rating': 4, 'comment': 'Tasty burger'}
# Feedback Sent: {'user': 'Charlie', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast delivery'}
# Feedback Sent: {'user': 'David', 'restaurant': 'KFC', 'rating': 3, 'comment': 'Average food'}
# Feedback Sent: {'user': 'Alice', 'restaurant': 'Pizza Hut', 'rating': 5, 'comment': 'Great pizza!'}
# Feedback Sent: {'user': 'Bob', 'restaurant': 'Burger King', 'rating': 4, 'comment': 'Tasty burger'}
# Feedback Sent: {'user': 'Charlie', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast delivery'}
# Feedback Sent: {'user': 'David', 'restaurant': 'KFC', 'rating': 3, 'comment': 'Average food'}
# Feedback Sent: {'user': 'Alice', 'restaurant': 'Pizza Hut', 'rating': 5, 'comment': 'Great pizza!'}
# Feedback Sent: {'user': 'Bob', 'restaurant': 'Burger King', 'rating': 4, 'comment': 'Tasty burger'}
# Feedback Sent: {'user': 'Charlie', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast delivery'}
# Feedback Sent: {'user': 'David', 'restaurant': 'KFC', 'rating': 3, 'comment': 'Average food'}
# Feedback Sent: {'user': 'Alice', 'restaurant': 'Pizza Hut', 'rating': 5, 'comment': 'Great pizza!'}
# Feedback Sent: {'user': 'Bob', 'restaurant': 'Burger King', 'rating': 4, 'comment': 'Tasty burger'}
# Feedback Sent: {'user': 'Charlie', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast delivery'}
# Feedback Sent: {'user': 'David', 'restaurant': 'KFC', 'rating': 3, 'comment': 'Average food'}
# Feedback Sent: {'user': 'Alice', 'restaurant': 'Pizza Hut', 'rating': 5, 'comment': 'Great pizza!'}
# Feedback Sent: {'user': 'Bob', 'restaurant': 'Burger King', 'rating': 4, 'comment': 'Tasty burger'}
# Feedback Sent: {'user': 'Charlie', 'restaurant': 'Dominos', 'rating': 5, 'comment': 'Fast delivery'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 27
#      23 producer.send('feedback_topic', value=data)
#      25 print("Feedback Sent:", data)
# ---> 27 time.sleep(4)
#
# KeyboardInterrupt:
